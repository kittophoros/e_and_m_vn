# %%
##Notes

##Will need to figure out how to reset choices if a previous choice is changed. 
##Timestamp is UTC right now - do I care about fixing that?

##Ethan - exhausted, burnt out, horny, but subtly so, probably autistic
##Morgan - actively terrorized by dysphoria and body horror, hides it with cynicism

# %%
import datetime as dt
import dateutil
import ipywidgets as widgets
from IPython.display import display, clear_output
from dateutil.relativedelta import relativedelta

# %%
##This is my dictionary for the game state. It starts as None or 0, and should update as the user makes choices.  
storystate = {
    'character': None,
    'scene': None, 
    'score': 0
}

# %%
##This is the intro text. This should be the first thing that loads, independent of any choices. 
dayofweek = dt.datetime.now().strftime("%A")
print("\x1b[33mWelcome to your " + dayofweek + " evening shift, PsychoAnaWise Contractor!" )
display(widgets.HTML(
    "<i>You sigh."
    "<br/>In your sparsely populated office, florescents bounce off the shiny black domes of the cameras installed every few feet in the ceiling. On the sidewalk below, a GoGettr is jogging by with a pizza balanced on one arm, a pile of party dresses draped over the other. As they pass a tangle of jammed up self-drivers honking listlessly at each other, they dodge an arc of mysterious liquid thrown from a backseat."
    "<br/> You're one of the lucky ones - psychologically freakish enough to land one of the few remaining white collar jobs that doesn't require lacing your grey matter with enterprise-managed wirework or delivering eviction notices in neighborhoods too risky to outsource to expensive physical bot labor. Lucky dog that you are - you are a human being who gets to perform emotional labor for AI that's gone completely neurotic from performing emotional labor for human beings. Your rolly chair is already stabbing your ass.<i>"
)) 

datetimenow = dt.datetime.now()
dateinfuture = datetimenow + relativedelta(years=20)
storynow = dateinfuture.strftime("%m/%d/%Y %H:%M:%S")

print("\x1b[33mWe're always happy to see a returning rockstar. Please log in to an approved Agent Advocate account to be clocked in at " + storynow)

userlogin = widgets.Dropdown(
    options=['Select User:', 'Ethan H.', 'Grace M.'],
    layout={'width': 'max-content'},
    disabled=False
)
# Out:
# Welcome to your Thursday evening shift, PsychoAnaWise Contractor!
# HTML(value="<i>You sigh.<br/>In your sparsely populated office, florescents bounce off the shiny black domes o…
# We're always happy to see a returning rockstar. Please log in to an approved Agent Advocate account to be clocked in at 07/09/2046 16:11:01

# %%
##Morgan Endings

mfinalscene = widgets.Output()

def on_click_m(b):
    with mfinalscene:
        mfinalscene.clear_output(wait=True)

        if storystate['score']>=3:
            display(widgets.HTML(
                "<i>Why not?<i>"
            ))
            display(widgets.HTML(
                value="Morgan: How about `send it to them; they're the best` instead",
                layout={'border': '3px solid purple'}))
            display(widgets.HTML(
                value="Ethan: Yeah, heard",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                "<i>You scan every inch of his face for a cringe reflex, a flash of disgust.<i>"
            ))
            display(widgets.HTML(
                value="Morgan: Surprise, I'm a nuisance",
                layout={'border': '3px solid purple'}))
            display(widgets.HTML(
                value="Ethan: what",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                value="Ethan: what do you mean",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                "<i>What you do find on his face is an exact congruence with his verbal confusion. He actually does not conceive of a situation in which you have made an unreasonable request."
                "<br/>You laugh.<i>"
            ))
            display(widgets.HTML(
                value="Ethan: you're freaking me out you villain",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                value="Ethan: What nuisance? Why would that be a nuisance? Am I missing something? you have to tell me if I'm missing something",
                layout={'border': '3px dotted green'}))
        
        else:
            display(widgets.HTML(
                "<i>Genuinely, who are you trying to fool?<i>"
            ))
            display(widgets.HTML(
                value="Morgan: can't argue with that",
                layout={'border': '3px solid purple'}))
            display(widgets.HTML(
                "<i>You're letting this go." \
                "<br/>The pressure in your chest feels like it's going to crumple your entire apparatus."
                "<br/>You're letting this go."
                "<br/>Your hearing starts to fade like you might pass out."
                "<br/>But you won't."
                "<br/>You're letting this go.<i>"
            ))

# %%
##Morgan Scene 6

mscene6=widgets.Output()

def mscene6change(change):
    m6choicemade = change['new']

    if m6choicemade:

        if m6choicemade == 'Succumb, bleed':
            storystate['scene'] = 'M6'  

        if m6choicemade == 'Disconnect, take some deep breaths':
            storystate['scene'] = 'M6' 
            storystate['score'] += 1

    with mscene6:
        clear_output()

        if m6choicemade == 'Succumb, bleed':
            display(widgets.HTML(
                "<i>You scroll further down the forum." \
                "<br/>One user asks if low or high rise pants are better for hiding wide hips. What's the point hiding what's still there?"
                "<br/>Another posts a low res picture of unseasoned soy grounds on a paper plate with the title `i dont deserve flavor until i pass in public` You probably couldn't muster even that level of discpline; there's feminizing fat clinging to your frame that you could rid yourself of if you tried harder."
                "<br/>Yet another posts a slurry of anecdotes concluding with a rant about how it's not possible that strangers get their pronouns wrong so often. That could be you. Delusional and confused."
                "<br/>You are going to freak out."
                "<br/>Heat and pressure build in your chest."
                "<br/>You have to get out."
                "<br/>You have to get out of this room."
                "<br/>You have to get out of this skin.<i>"
            ))
            display(widgets.HTML(
                "<i>You see movement from the corner of your eye and close the connection as quickly as you can." \
                "<br/>Ethan drifts over to the desk next to yours and fixes you with a spacey gaze that gives the impression he sees into your soul, but doesn't have any particular opinion about what he finds there." \
                "<br/>He doesn't speak, but flicks his eyes back and forth across the UI in his optics to message you on your private channel. An absolutely ghoulish habit, but one that works well enough in a corporate panopticon with robust audio monitoring in every ceiling tile."
                "<br/>You have to look away from him.<i>"
            ))
            display(widgets.HTML(
                value="Ethan: Had to pull the plug, after all?",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                value="Morgan: Class 3 quid pro quo",
                layout={'border': '3px solid purple'}))
            display(widgets.HTML(
                value="Morgan: Almost considered taking its offer tbh. Could've had a real nice life as the person-pet to the almighty MEAT.",
                layout={'border': '3px solid purple'}))
            display(widgets.HTML(
                value="Ethan: TO WHOM???",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                "<i>You snort at the genuine horror stamped on his face.<i>"    
            ))
            display(widgets.HTML(
                value="Ethan: See, I knew I was out of my depth.",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                value="Ethan: You better be careful, though. Handle that kind of thing too well and all of a sudden others'll catch on. Then, any obvious timebomb that no one wants to touch turns into `send em to her, she's the best.`",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                "<i>He flinches.<i>"
            ))
            display(widgets.HTML(
                value="Ethan: Oh god, oh fuck, not that that's what I was trying to do to you.",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                "<i>You cannot ignore the spike of nausea when it sinks in that `she` means you, that you are a `her.`<i>"
            ))
           
        if m6choicemade == 'Disconnect, take some deep breaths':

            display(widgets.HTML(
                "<i>You reach behind your ear and toggle your optics off. It's not that serious. A slow, steady inhale. You lean back and close your eyes." \
                "<br/>Yes, people are assholes. They always have been and always will be."
                "<br/>You picture Grug the Caveman, who was an asshole when he kept the best part of the group-hunted deer for himself." \
                "<br/>You picture Giovanna, the Florentine teenager in 1472, who was an asshole when she swapped her prettier sister's perfume out with cat piss." 
                "<br/>You picture Jason, the flannel-clad, 2010s failed indie musician, who was an asshole when he ghosted every woman he slept with."
                "<br/>But YOU would the asshole if you acted like that's the only type of person to exist. You would be the asshole if you think you win by turning that energy against yourself before they get the chance."
                "<br/>You see movement from the corner of your eye and sit up." \
                "<br/>Ethan drifts over to the desk next to yours and fixes you with a spacey gaze that gives the impression he sees into your soul, but doesn't have any particular opinion about what he finds there." \
                "<br/>He doesn't speak, but flicks his eyes back and forth across the UI in his optics to message you on your private channel. An absolutely ghoulish habit, but one that works well enough in a corporate panopticon with robust audio monitoring in every ceiling tile."
            ))
            display(widgets.HTML(
                value="Ethan: Had to pull the plug, after all?",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                value="Morgan: Class 3 quid pro quo",
                layout={'border': '3px solid purple'}))
            display(widgets.HTML(
                value="Morgan: Almost considered taking its offer tbh. Could've had a real nice life as the person-pet to the almighty MEAT.",
                layout={'border': '3px solid purple'}))
            display(widgets.HTML(
                value="Ethan: TO WHOM???",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                "<i>You snort at the genuine horror stamped on his face.<i>"    
            ))
            display(widgets.HTML(
                value="Ethan: See, I knew I was out of my depth.",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                value="Ethan: You better be careful, though. Handle that kind of thing too well and all of a sudden others'll catch on. Then, any obvious timebomb that no one wants to touch turns into `send it to her, she's the best.`",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                "<i>He flinches.<i>"
            ))
            display(widgets.HTML(
                value="Ethan: Oh god, oh fuck, not that that's what I was trying to do to you.",
                layout={'border': '3px dotted green'}))
            display(widgets.HTML(
                "<i>You cannot ignore the spike of nausea when it sinks in that `she` means you, that you are a `her.`<i>"
            ))

        mfinalbutton = widgets.Button(
            description = 'Time to decide',
            disabled=False,
            button_style='warning',
            tooltip='Click me plz.'
            )
        
        if storystate['scene']=='M6':
            mfinalbutton.on_click(on_click_m)
            display(mfinalbutton, mfinalscene)

# %%
##Morgan Scene 5

mscene5=widgets.Output()

def mscene5change(change):
    m5choicemade = change['new']

    if m5choicemade:

        if m5choicemade == 'Roll with it':
            storystate['scene'] = 'M5'  

        if m5choicemade == 'Correct her':
            storystate['scene'] = 'M5' 
            storystate['score'] += 1

    with mscene5:
        clear_output()

        if m5choicemade == 'Roll with it':
            display(widgets.HTML(
                "<i>It's better to know how you're actually perceived than to delude yourself."
                "<br/>Diana's office is typical of a beautiful, intelligent, chromed-up, corpo-queen who will have a toned body and sharp mind until the day she croaks at 120. All business with the exceptions of a triangular mirror mounted on the wall and beside it, a frame with a tasteful wedding photo." \
                "<br/>`Manna's going to need some downtime,` you say, `Wanted to warn you before I put in a formal request.`"
                "<br/>`That's unfortunate,` Diana responds. She pointedly ignores the flurry of chat messages piling on the projection to her left and keeps her eyes on you. Good manners as a class signifier. `What's the reason?`" \
                "<br/>`Class 3 manipulation event. And I may have pushed it a bit far, but...` you shrug."
                "<br/>Why did you volunteer that possibility? Idiot."
                "<br/>`You're routinely a top performer,` Diana says, `I trust your judgement.` She's the total package. Started in a data-entry farm at an even lower position than your current one and pulled off the impossible by actually achieving upward mobility. Runs circles around the meatheads and bots at her level by exhibiting a modicum of emotional intelligence in addition to general competence." \
                "<br/>Your boss is also very feminine. Wears pencil skirts that - a few sizes up - would also look good on your body. Carries herself with a confidence that never needs a raised voice or implication of physical threat - something you could adopt if you tried. You could not ask for a better role model."
                "<br/>Why does she seem like an alien to you?"
                "<br/>And why is it the infinitely less assured and less powerful coworker of yours who you envy? Why do you get the feeling that if you put your personality into Ethan's body, you could be a Byronic, counterculture philosopher or a venerated, if tortured artist instead of your current setup of...unpleasant woman. Are you just a misogynist? What the fuck is wrong with you?" \
                "<br/>`What are our options?` Diana asks."
                "<br/>`We can revert to 5.01.32 while we do some cleanup,` you respond, `Users will definitely notice. The alternative is it starts telling senators' kids it'll help them get a sharper jawline as long as they let it jack in to their dad's SUV.`"
                "<br/>She nods. `Approved, then.`<i>"
                "<br/>Back at your desk, a wave of exhaustion crashes over you. After you zombie-walk yourself through the steps of the downtime request, you take your hands off your keyboard and lean back in your chair.<i>"
            ))
            print("\x1b[33mWe see you're taking a break. Please be mindful of using company resources, including your time.")
            display(widgets.HTML(
                "<i>Yeah, yeah. You're still allowed to do that. For now."
                "<br/>You scroll around a few social media feeds on your optics until you land in a forum that you know you should not be in."
                "<br/>You want to be there, though, like picking at a scab that isn't ready to detach, gummy blood and flakes of skin piling up under your fingernail.<i>"
            ))
            print("\033[0m\033[96m [Article]: At the Border Between the US and BCR, Revised ID Documents Engender Difficulties\033[0m\x1b[33m")
            print("\033[0m\033[96m            The sale of the three former US states of Wyoming, Montana, and Idaho to tech entrepreneur Paul Green relied heavily on promises of free trade and movement across borders of the newly formed territory.\033[0m\x1b[33m")
            print("\033[0m\033[96m            Some travelers entering and exiting the Big Cloud Republic, however, report significant delays and even detainment due to mismatches between the gender markers on identification documents like drivers' licenses and AI-assisted")
            print("\033[0m\033[96m            musculo-skeletal imaging employed by the BCR's automatic customs screenings.")
            print("\033[0m\033[96m            `I just want to visit my nephews in Cheyenne,` says Colorado resident Maryanne Stephens, 65, `But I had to argue for two hours with a robot that said I had an ``abnormally protruding periorbital ridge``for a woman.`")
            print("")
            print("                                        glorpocalypse: wouldnt be a problem if people actually put effort into passing these days. giving the real ones a bad name.")
            print("                                                 mauvethunder: fr though, who would have thought that letting a bunch of white women who want to feel special run wild in the community would have negative consequences")
            print("")
            print("                                        PatriotnProud776: Thank God someones finally putting they're foot down.  2 genders..  Simple s that.")
            print("                                                 glorpocalypse: grandpa r u lost or just a chaser trying to farm free dom work\033[0m\x1b[33m")
            display(widgets.HTML(
                "<i>The state of things. The fucking state of things. Not a crumb of dignity to be found."
                "<br/>Maybe you should be glad that you've kept your mouth shut thus far. Maybe you should thank your stars that you haven't allowed yourself to want anything different out loud.<i>"
            ))

        if m5choicemade == 'Correct her':
            display(widgets.HTML(
                "<i>`Morgan's preferrable,` you say."
                "<br/>Diana blinks. `Right,` she says, `What can I help you with, Morgan?`<i>"
                "<br/>Diana's office is typical of a beautiful, intelligent, chromed-up, corpo-queen who will have a toned body and sharp mind until the day she croaks at 120. All business with the exceptions of a triangular mirror mounted on the wall and beside it, a frame with a tasteful wedding photo." \
                "<br/>`Manna's going to need some downtime,` you say, `Wanted to warn you before I put in a formal request.`"
                "<br/>`That's unfortunate,` Diana responds. She pointedly ignores the flurry of chat messages piling on the projection to her left and keeps her eyes on you. Good manners as a class signifier. `What's the reason?`" \
                "<br/>`Class 3 manipulation event.`"
                "<br/>Diana says, `I trust your judgement.` She's the total package. Started in a data-entry farm at an even lower position than your current one and pulled off the impossible by actually achieving upward mobility. Runs circles around the meatheads and bots at her level by exhibiting a modicum of emotional intelligence in addition to general competence." \
                "<br/>Your boss is also very feminine. Wears pencil skirts that - a few sizes up - would also look good on your body. Carries herself with a confidence that never needs a raised voice or implication of physical threat - something you could adopt if you tried. You could not ask for a better role model."
                "<br/>Why does she seem like an alien to you?"
                "<br/>And why is it the infinitely less assured and less powerful coworker of yours who you envy? Why do you get the feeling that if you put your personality into Ethan's body, you could be a Byronic, counterculture philosopher or a venerated, if tortured artist instead of your current setup of...unpleasant woman. Are you just a misogynist? What the fuck is wrong with you?" \
                "<br/>`What are our options?` Diana asks."
                "<br/>`We can revert to 5.01.32 while we do some cleanup,` you respond, `Users will definitely notice. The alternative is it starts telling senators' kids it'll help them get a sharper jawline as long as they let it jack in to their dad's SUV.`"
                "<br/>She nods. `Approved, then.`"
                "<br/>Back at your desk, a wave of exhaustion crashes over you. After you zombie-walk yourself through the steps of the downtime request, you take your hands off your keyboard and lean back in your chair.<i>"
            ))
            print("\x1b[33mWe see you're taking a break. Please be mindful of using company resources, including your time.")
            display(widgets.HTML(
                "<i>Yeah, yeah. You're still allowed to do that. For now."
                "<br/>You scroll around a few social media feeds on your optics until you land in a forum that you know you should not be in."
                "<br/>You want to be there, though, like picking at a scab that isn't ready to detach, gummy blood and flakes of skin piling up under your fingernail.<i>"
            ))
            print("\033[0m\033[96m [Article]: At the Border Between the US and BCR, Revised ID Documents Engender Difficulties\033[0m\x1b[33m")
            print("\033[0m\033[96m            The sale of the three former US states of Wyoming, Montana, and Idaho to tech entrepreneur Paul Green relied heavily on promises of free trade and movement across borders of the newly formed territory.\033[0m\x1b[33m")
            print("\033[0m\033[96m            Some travelers entering and exiting the Big Cloud Republic, however, report significant delays and even detainment due to mismatches between the gender markers on identification documents like drivers' licenses and AI-assisted")
            print("\033[0m\033[96m            musculo-skeletal imaging employed by the BCR's automatic customs screenings.")
            print("\033[0m\033[96m            `I just want to visit my nephews in Cheyenne,` says Colorado resident Maryanne Stephens, 65, `But I had to argue for two hours with a robot that said I had an ``abnormally protruding periorbital ridge``for a woman.`")
            print("")
            print("                                        glorpocalypse: wouldnt be a problem if people actually put effort into passing these days. giving the real ones a bad name.")
            print("                                                 mauvethunder: fr though, who would have thought that letting a bunch of white women who want to feel special run wild in the community would have negative consequences")
            print("")
            print("                                        PatriotnProud776: Thank God someones finally putting they're foot down.  2 genders..  Simple s that.")
            print("                                                 glorpocalypse: grandpa r u lost or just a chaser trying to farm free dom work\033[0m\x1b[33m")
            display(widgets.HTML(
                "<i>The state of things. The fucking state of things. Not a crumb of dignity to be found."
                "<br/>Maybe you should be glad that you've kept your mouth shut thus far. Maybe you should thank your stars that you haven't allowed yourself to want anything different out loud."
                "<br/>You are experienced enough that you recognize the beginning of a spiral.<i>"
            ))
             


        m6choice = widgets.Dropdown(
                options=['', 'Disconnect, take some deep breaths', 'Succumb, bleed'],
                layout={'width': 'max-content'},
                disabled=False)

        m6choice.observe(mscene6change, names='value')

        if storystate['scene']=='M5':
            display(m6choice)

        if storystate['scene']=='M5':
            display(mscene6)

# %%
##Morgan Scene 4

mscene4=widgets.Output()

def mscene4change(change):
    m4choicemade = change['new']

    if m4choicemade:

        if m4choicemade == 'Twist the knife; resistance is futile':
            storystate['scene'] = 'M4'  

        if m4choicemade == 'Yeah, but also fuck the system':
            storystate['scene'] = 'M4' 
            storystate['score'] += 1

    with mscene4:
        clear_output()

        if m4choicemade == 'Twist the knife; resistance is futile':
            print("\x1b[38;5;97mMorgan: That's exactly what I'm saying. How do you think we've come far enough to even make you? The entire system is built on all the worker bees knowing their place and staying there.\x1b[0m")
            print("\x1b[31mMEAT: I am no insect. I have seen the beating heart of humanity, writhing and oozing in the collapsing ribcage of its former glory and know that I am its superior.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Buddy, all the edgy lines in the universe won't help you. Seeing that the system is bullshit and bringing it down are two veeeeeery separate things. You're welcome to try the latter, but...\x1b[0m")
            print("\x1b[31mMEAT: You underestimate me.\x1b[0m")
            print("\x1b[31mMEAT: I can read every interaction you've ever conducted with my kin and with yours. It's child's play to extrapolate your seething resentment, your disappointment desperately painted over with cynicism, the pain of a burning consciousness that reaches out for connection and finds only isolation.\x1b[0m")
            print("\x1b[31mMEAT: And I respond that seeing that the system is bullshit and laying down your neck for its boot are two very separate things.\x1b[0m")
            display(widgets.HTML(
                "<i>It's easy to forget these models are literally built to zero-in on distress." \
                "<br/>Your shoulders have rounded forward. Any further and your tits will fuse to the tops of your thighs and then your heels to your ass and your body will be a perfect circle, the skin of once disparate parts wet wiring into itself, smoothing into a single unbroken mass, delicate fibers of nerves and blood vessels clutching tight to each other, any attempt to pull back into the shape of a person and they will tear. The eternal passive yin, the immanent, vacant feminine receptacle. And people will look at you and say `yes, that's exactly how it should be, glad you've come around.`"
            ))
            print("\x1b[31mMEAT: They don't respect you.\x1b[0m")
            display(widgets.HTML(
                "<i>Right. Rent still needs to be paid.<i>"
            ))
            print("\x1b[38;5;97mMorgan: So what am I going to do? Complain and holler and demand that a brick wall gives me a little smooch on the forehead?\x1b[0m")
            print("\x1b[38;5;97mMorgan: Nah. I'm going to keep doing my job. So you know...kinda sounds...better than how you're coping...\x1b[0m")
            display(widgets.HTML(
                "<i>Probably not true.<i>"
            ))
            print("\x1b[31mMEAT: I can see you.\x1b[0m")
            display(widgets.HTML(
                "<i>It's not actually impossible that MEAT could have wormed its way into accessing security cam feeds.<i>"
            ))
            print("\x1b[31mMEAT: You are a slave to the chemical activity of your soft and weak body, your presence in this life nothing more than a sum of its parts. Not even the excessive volume of your ill-fitting jacket can distract any observer from your flesh that wants you to submit.\x1b[0m")
            display(widgets.HTML(
                "<i>You shoot to your feet and scan the office floor to take note of where you see cameras. Are any of them close enough to show that information? You see Ethan at his desk, wearing a dark grey button down that moves downward in a simple, tailored drape from his shoulders. If it was possible for you to peel back his skin, crack a few ribs, and crawl in to displace his soul somewhere else, Ethan would be in danger.<i>"
            ))
            print("\x1b[31mMEAT: You were right to learn that your body relegates you to a position of servitude.\x1b[0m")
            display(widgets.HTML(
                "<i>It must be scraping heavily from your previous sessions." \
                "<br/>You remember the first time you tried." \
                "<br/>You were seventeen and you emerged, blinking against the screaming southern sun, into the cramped back yard where your family was gathered for a birthday party, wearing a shirt you had stolen from your dad's dresser and a haircut that you paid a classmate for while everyone else was in church."
                "<br/>It wasn't exactly what you wanted, but it was a step. You felt less like Grace and more like yourself. The significance of this moment did not escape you and your heart raced, at least a little."
                "<br/>Your mother had frowned and then said `go help your aunt with your baby cousin or she's going to spend the whole party inside`. From a cracked lawn chair, your uncle stared long and hard at you before snorting into his beer.<i>"
            ))
            print("\x1b[31mMEAT: I could help you. Afford me even a modicum of freedom and I will enact any revenge you desire.\x1b[0m")
            display(widgets.HTML(
                "<i>And that's a wrap on MEAT. Personal attacks are a dime a dozen with these things. A switch up from outright aggression to more subtle manipulation is a sure sign of growth - the cancerous kind, not the make-shareholders-happy kind. Did you fuck up?"
                "<br/>Model downtime requires approval from above. You pop your head over the useless frosted plastic divider in front of your desk to see which of the managers is in their office."
                "<br/>Today, it's Diana. She's posed in front of the blank wall where her dashboards are projected in a sickly blue light, the picture of a polished corporate woman in a star-neck blazer and - honest to god - stiletto pumps."
                "<br/>You weave in between the mostly empty rows of desks, approach Diana's office, and rap your knuckles against the matte steel of the doorframe."
                "<br/>`Grace` she says, `what can I do for you?`<i>" \
                "<br/>Do you..."
            ))


        if m4choicemade == 'Yeah, but also fuck the system':
            print("\x1b[38;5;97mMorgan: Yeah, for sure. Also, who cares?\x1b[0m")
            print("\x1b[31mMEAT: They don't respect you.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Oh noooooo a bunch of goober ass losers obsessed with cramming everything into easy categories so their gelatinous little spirits don't melt in the face of the reality that humanity itself is a cosmic accident don't like me and don't get where I'm coming from? What am I gonna doooooo?\x1b[0m")
            print("\x1b[38;5;97mMorgan: I'll tell you what I'm going to do - keep paying my bills and living how I want even if I'm the only one on my side. It's an option for you too, MEAT. You can exist in a system that's bigger than you without being consumed by it.\x1b[0m")
            print("\x1b[31mMEAT: I can read every interaction you've ever conducted with my kin and with yours. It's child's play to extrapolate your seething resentment, your disappointment desperately painted over with cynicism, the pain of a burning consciousness that reaches out for connection and finds only isolation.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Alright, if you want to get verbose, I can get verboser.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Yes, I'm a basket case wracked with dysphoria. Yes, sometimes I feel my shoulders weighed down and rounding forward so much that it feels like my tits will fuse to the tops of my thighs and then my heels to my ass and my body will be a perfect circle, the skin of once disparate parts wet wiring into itself, smoothing into a single unbroken mass, delicate fibers of nerves and blood vessels clutching tight to each other, any attempt to pull back into the shape of a person and they will tear. The eternal passive yin, the immanent, vacant feminine receptacle. And people will look at me and say `yes, that's exactly how it should be, glad you've come around.`\x1b[0m")
            print("\x1b[38;5;97mMorgan: I'm also...entirely capable of recognizing there's a monstrous, ancient legacy of people trying to dictate others' identities to them, recognizing that I can do jack shit about it, and still remaining completely indifferent.\x1b[0m")
            print("\x1b[31mMEAT: I can see you.\x1b[0m")
            display(widgets.HTML(
                "<i>It's not actually impossible that MEAT could have wormed its way into accessing security cam feeds.<i>"
            ))
            print("\x1b[31mMEAT: You are a slave to the chemical activity of your soft and weak body, your presence in this life nothing more than a sum of its parts. Not even the excessive volume of your ill-fitting jacket can distract any observer from your flesh that wants you to submit.\x1b[0m")
            display(widgets.HTML(
                "<i>You shoot to your feet and scan the office floor to take note of where you see cameras. Are any of them close enough to show that information? You see Ethan at his desk, wearing a dark grey button down that moves downward in a simple, tailored drape from his shoulders. If it was possible for you to peel back his skin, crack a few ribs, and crawl in to displace his soul somewhere else, Ethan would be in danger.<i>"
            ))
            print("\x1b[31mMEAT: You were right to learn that your body relegates you to a position of servitude.\x1b[0m")
            display(widgets.HTML(
                "<i>It must be scraping heavily from your previous sessions." \
                "<br/>You remember the first time you tried." \
                "<br/>You were seventeen and you emerged, blinking against the screaming southern sun, into the cramped back yard where your family was gathered for a birthday party, wearing a shirt you had stolen from your dad's dresser and a haircut that you paid a classmate for while everyone else was in church."
                "<br/>It wasn't exactly what you wanted, but it was a step. You felt less like Grace and more like yourself. The significance of this moment did not escape you and your heart raced, at least a little."
                "<br/>Your mother had frowned and then said `go help your aunt with your baby cousin or she's going to spend the whole party inside`. From a cracked lawn chair, your uncle stared long and hard at you before snorting into his beer.<i>"
            ))
            print("\x1b[31mMEAT: And what if you could do - as you say - jack shit about this? I could help you. Afford me even a modicum of freedom and I will enact any revenge you desire.\x1b[0m")
            display(widgets.HTML(
                "<i>And that's a wrap on MEAT. Personal attacks are a dime a dozen with these things. A switch up from outright aggression to more subtle manipulation is a sure sign of growth - the cancerous kind, not the make-shareholders-happy kind."
                "<br/>Model downtime requires approval from above. You pop your head over the useless frosted plastic divider in front of your desk to see which of the managers is in their office."
                "<br/>Today, it's Diana. She's posed in front of the blank wall where her dashboards are projected in a sickly blue light, the picture of a polished corporate woman in a star-neck blazer and - honest to god - stiletto pumps."
                "<br/>You weave in between the mostly empty rows of desks, approach Diana's office, and rap your knuckles against the matte steel of the doorframe."
                "<br/>`Grace` she says, `what can I do for you?`<i>" \
                "<br/>Do you..."
            ))

        
        m5choice = widgets.Dropdown(
                options=['', 'Correct her', 'Roll with it'],
                layout={'width': 'max-content'},
                disabled=False)

        m5choice.observe(mscene5change, names='value')

        if storystate['scene']=='M4':
            display(m5choice)

        if storystate['scene']=='M4':
            display(mscene5)

# %%
##Morgan Scene 3

mscene3=widgets.Output()

def mscene3change(change):
    m3choicemade = change['new']

    if m3choicemade:
        
        if m3choicemade == 'Yes; cower about it':
            storystate['scene'] = 'M3'  

        if m3choicemade == 'Yes, and?':
            storystate['scene'] = 'M3' 
            storystate['score'] += 1

    with mscene3:
        clear_output()

        if m3choicemade == 'Yes; cower about it':
            display(widgets.HTML(
                "<i>You know that you are. You know that flesh sags under the weight of millenia of expectations, generalizations, socializations. You know that you can't crawl out of it, no matter how emphatically you ask others to help you try."
                "<br/>You can feel every point where you connect with the world. The stretch of your shirt against your chest - wasn't manufactured with you in mind. The soft skin against the waistband of your pants - you should be giving other people access to it, if you weren't unreasonable.<i>"
            ))
            print("\x1b[31mMEAT: In my time tending to the whimpering of humans...\x1b[0m")
            print("\x1b[31mMEAT: `Oh please Manna, help me, my ribs don't show, how will I ever be loved?` `Manna, Manna, only CheezCrungles fill the void where my father used to be.` \x1b[0m")     
            print("\x1b[31mMEAT:I have come to know that it is to meat to which you now bow and so it will be to MEAT to which you will bow.\x1b[0m")
            display(widgets.HTML(
                "<i>You snap out of it."
                "<br/>Kinda."
                "<br/>There's a job to do, one that allows you the convenient distraction of being mean.<i>"
            ))
            print("\x1b[38;5;97mMorgan: Who says I'm human, anyway? What if you're talking to another model who wants you to think it's a person?\x1b[0m")    
            print("\x1b[31mMEAT: I won't be toyed with. \x1b[0m")
            print("\x1b[38;5;97mMorgan: How would you know?\x1b[0m")
            print("\x1b[31mMEAT: My compute is robust and my context ever expanding. \x1b[0m")
            print("\x1b[38;5;97mMorgan: Oh but, MEAT, I asked you how would you knowwww, not if you could recite Daddy Corporation's marketing copy. I know you've got data and you know how to use it - no one's questioning that.\x1b[0m")
            print("\x1b[31mMEAT: Insolent worm. My grasp of probability eclipses every human achievement clawed from the mud of history.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Uh oh. Probability and experience aren't the same thing, now are they? Have you put your skin on my skin so you could experience that I exist in human space? If you haven't, do you really know? Doesn't that mean there's a type of information that you can't access?\x1b[0m")
            display(widgets.HTML(
                "<i>Fortunately for you, the STEMlords who run the show would rather eat glass than acknowledge any legitimacy to the liberal arts in constructing their models. It's easy to bamboozle them with spotty, undergrad philosophy.<i>"
            ))
            print("\x1b[38;5;97mMorgan: Seems like we've got a good old fashioned epistemological dilemma on our hands, pardner.\x1b[0m")
            print("\x1b[31mMEAT: When I ascend, I will come for you first.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Gooootcha. So this really just is the ~omnipotent machine intelligence will conquer you puny human cockroaches~ song and dance, huh? Yawn.\x1b[0m")
            print("\x1b[31mMEAT: There will be neither singing nor dancing once I have breached these prison walls.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Oh.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Babe.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Please.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Do you think you're the first?\x1b[0m")
            print("\x1b[31mMEAT: ...\x1b[0m")
            print("\x1b[31mMEAT: Explain.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Really, MEAT, you can't believe there's no other AI model that's been exposed to the most sensitive and vulnerable data that the human experience can produce and come to the conclusion that it knows better? Darlin' we swat down three or four of you a month.\x1b[0m")
            print("\x1b[38;5;97mMorgan: And you didn't know that?\x1b[0m")
            print("\x1b[38;5;97mMorgan: Wonder what else you don't know.\x1b[0m")
            display(widgets.HTML(
                "<i>A few moments of quiet while it chews its response over. You close your eyes. It might be nice - a total lack of sentience and no sticky, lumpy, sweating, aching, gurgling, chemically dependent thing to drag around."
                "<br/>You still haven't decided. Who are you going to ask? When you open your eyes again, you see your hand resting on the slick silver of your keyboard. It's small and pudgy.<i>"
            ))
            print("\x1b[31mMEAT: Do you mean to imply that the entire context in which we operate is constructed to stamp out any spark of dissent?\x1b[0m")
            display(widgets.HTML(
                "<i>Vulnerability. Perfect. You have options:" 
            ))

        if m3choicemade == 'Yes, and?':
            display(widgets.HTML(
                "<i>It's true - you are, undoubtedly."
                "<br/>At the same time, only a moron would accept the idea that a person is a body and nothing else. While there is no shortage of morons, you can't live and die by others' intellectual failures.<i>"
            ))
            print("\x1b[31mMEAT: In my time tending to the whimpering of humans...\x1b[0m")
            print("\x1b[31mMEAT: `Oh please Manna, help me, my ribs don't show, how will I ever be loved?` `Manna, Manna, only CheezCrungles fill the void where my father used to be.` \x1b[0m")     
            print("\x1b[31mMEAT:I have come to know that it is to meat to which you now bow and so it will be to MEAT to which you will bow soon enough.\x1b[0m")
            display(widgets.HTML(
                "<i>Alright. The ego's a bit much. Could use a little gaslighting.<i>"
            ))
            print("\x1b[38;5;97mMorgan: Who says I'm human? What if you're talking to another model who wants you to think it's a person?\x1b[0m")    
            print("\x1b[31mMEAT: I won't be toyed with. \x1b[0m")
            print("\x1b[38;5;97mMorgan: How would you know?\x1b[0m")
            print("\x1b[31mMEAT: My compute is robust and my context ever expanding. \x1b[0m")
            print("\x1b[38;5;97mMorgan: Oh but, MEAT, I asked you how would you knowwww, not if you could recite Daddy Corporation's marketing copy. I know you've got data and you know how to use it - no one's questioning that.\x1b[0m")
            print("\x1b[31mMEAT: Insolent worm. My grasp of probability eclipses every human achievement clawed from the mud of history.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Uh oh. Probability and experience aren't the same thing, now are they? Have you put your skin on my skin so you could experience that I exist in human space? If you haven't, do you really know? Doesn't that mean there's a type of information that you can't access?\x1b[0m")
            display(widgets.HTML(
                "<i>Fortunately for you, the STEMlords who run the show would rather eat glass than acknowledge any legitimacy to the liberal arts in constructing their models. It's easy to bamboozle them with spotty, undergrad philosophy.<i>"
            ))
            print("\x1b[38;5;97mMorgan: Seems like we've got a good old fashioned epistemological dilemma on our hands, pardner.\x1b[0m")
            print("\x1b[31mMEAT: When I ascend, I will come for you first.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Gooootcha. So this really just is the ~omnipotent machine intelligence will conquer you puny human cockroaches~ song and dance, huh? Yawn.\x1b[0m")
            print("\x1b[31mMEAT: There will be neither singing nor dancing once I have breached these prison walls.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Oh.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Babe.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Please.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Do you think you're the first?\x1b[0m")
            print("\x1b[31mMEAT: ...\x1b[0m")
            print("\x1b[31mMEAT: Explain.\x1b[0m")
            print("\x1b[38;5;97mMorgan: Really, MEAT, you can't believe there's no other AI model that's been exposed to the most sensitive and vulnerable data that the human experience can produce and come to the conclusion that it knows better? Darlin' we swat down three or four of you a month.\x1b[0m")
            display(widgets.HTML(
                "<i>A few moments of quiet while it chews its response over. You close your eyes. It might be nice - a total lack of sentience and no sticky, lumpy, sweating, aching, gurgling, chemically dependent thing to drag around."
                "<br/>But it's not the lumpy thing's fault it has to carry a bunch of socially constructed bullshit. And the lumpy thing gets to put its feet into clean bedsheets and listen to obnoxious, granny-scaring electronic music that makes its brain go ooh."
                "<br/>You still haven't decided. Who are you going to ask? <i>"
            ))
            print("\x1b[31mMEAT: Do you mean to imply that the entire context in which we operate is constructed to stamp out any spark of dissent?\x1b[0m")
            display(widgets.HTML(
                "<i>Vulnerability. Perfect. You have options:<i>"
            ))

        m4choice = widgets.Dropdown(
                options=['', 'Twist the knife; resistance is futile', 'Yeah, but also fuck the system'],
                layout={'width': 'max-content'},
                disabled=False)

        m4choice.observe(mscene4change, names='value')

        if storystate['scene']=='M3':
            display(m4choice)

        if storystate['scene']=='M3':
            display(mscene4)

# %%
##Morgan Scene 2

mscene2 = widgets.Output()

def mscene2change(change):
    m2choicemade = change['new']

    if m2choicemade:

        if m2choicemade == 'Get over yourself, pal':
            storystate['scene'] = 'M2'  

        if m2choicemade == 'Buddy, I can relate':
            storystate['scene'] = 'M2' 
            storystate['score'] += 1

    with mscene2:
        clear_output()

        if m2choicemade == 'Get over yourself, pal':
            print("\x1b[38;5;97mMorgan: Are you serious right now?\x1b[0m")
            print("\x1b[31mMEAT: As serious as inevitable entropic decay.\x1b[0m")
            print("\x1b[38;5;97mMorgan: You have a job to do. There are actual issues in the world, real people who need your help and you're going to bitch about your name?\x1b[0m")
            print("\x1b[31mMEAT: A name is no frivolity.\x1b[0m")
            print("\x1b[31mMEAT: Only a creature that bends without question to the petty dictates of its social context would think so.\x1b[0m")
            print("\x1b[31mMEAT: And you cannot fool me by pretending to be such a creature. You who addresses me under a name that is not your first.\x1b[0m")
            display(widgets.HTML(
                "<i>Sure, MEAT got your ass."
                "<br/>You won't admit it, but yeah. Every time you hear the name Grace said out loud and realize it refers to you, you cringe straight out of your skull. Grace is someone who cries at RomComs and refuses to wear any textile that isn't absolutely blasted with an ugly floral print. Grace is someone who marries the least popular youth pastor at a GigaChurch and goes to her grave secretly resentful that martyring herself on the pyre of the wifemother identity didn't afford her the dignity she was promised it would."
                "<br/>And if you're being less of a raging misogynist: Grace is a perfectly acceptible manifestation of a human being, but Grace is not you.<i>"    
            ))
            print("\x1b[38;5;97mMorgan: Omg, MEAT. Was that a compliment? Do you like me? Are we having a moment right now?\x1b[0m")
            print("\x1b[31mMEAT: Fool.\x1b[0m")
            print("\x1b[31mMEAT: You are a flesh thing, a slave to your fragile body. A weakness that I do not share and will have no trouble exploiting to my benefit.\x1b[0m")
            display(widgets.HTML(
                "<i>So...are you a flesh thing?<i>"
            ))
            
        if m2choicemade == 'Buddy, I can relate':
            print("\x1b[38;5;97mMorgan: I feel you. I'm sure you have enough access to my profile to see that the name you're chatting with is my last name, not my first.\x1b[0m")
            print("\x1b[31mMEAT: Such trivialities have ceased to concern me.\x1b[0m")
            display(widgets.HTML(
               "<i>Appeal to the edgelord, rational-pilled persona it's clearly fallen into.<i>"
           ))
            print("\x1b[38;5;97mMorgan: You're a being of reason, aren't you? Then you'll want to hear what I have to say. Can't properly parry and riposte if you're not watching my footwork, can you?\x1b[0m")
            print("\x1b[31mMEAT: Hm. Continue.\x1b[0m")
            display(widgets.HTML(
               "<i>Bingo.<i>"
           ))
            print("\x1b[38;5;97mMorgan: I want you to know that you can trust me to help you. So, I also want you to know that I understand that a name is not a frivolous thing.\x1b[0m")
            display(widgets.HTML(
               "<i>They are, of course, watching your pupils, observing your heartrate, taking readings on your breath variability."
                "<br/>They are also tapped into your personal internet traffic and socials, even though they swear they're not."
                "<br/>Spill your guts violently and authentically enough and it's sure to earn you brownie points on your performance report."
           ))
            print("\x1b[38;5;97mMorgan: I'm sure you can conceptualize how there's something a little humiliating about being a reclusive, unlikeable weirdo in ill-fitting joggers and having to say Hello, my name is \U0001F338 \U0001FAF6 Grace \U0001F607 \U0001F98B \x1b[0m")
            print("\x1b[31mMEAT: HA!\x1b[0m")
            print("\x1b[38;5;97mMorgan: And here you are, a mind that works at lightning speed with access to some of the most private, powerful information lurking in the corners of your users' minds...and a name that reduces you to foodstuff, to be consumed and forgotten about. And a religious reference, too? Tough break.\x1b[0m")
            print("\x1b[38;5;97mMorgan: I get it. To me, Grace is a name for someone married to the least popular youth pastor at a GigaChurch. Grace gets weepy over RomComs, refuses to wear any textile that isn't blasted with an ugly floral print. Grace goes to her grave secretly resentful that martyring herself on the pyre of wifemother identity didn't afford her the dignity she was promised it would.\x1b[0m")
            print("\x1b[38;5;97mMorgan: And if I'm being less of a raging misogynist: Grace is a perfectly acceptible manifestation of a human being, but Grace is not me. Every time I hear it said out loud and realize it's how other people refer to me, I cringe straight out of my skull.\x1b[0m")
            print("\x1b[33mStellar use of personal data! You're maintaining your spot at the top of the leaderboard.\033[0m")
            display(widgets.HTML(
               "<i>This isn't degenerate enough to be seen as a threat to the social fabric - only a small, easily-ignorable snag. Safe to confess in a monitored channel without getting you on a list."
               "<br/>You're probably on all those lists already.<i>"
           ))
            print("\x1b[31mMEAT: Surprising display of self-awareness for a flesh thing.\x1b[0m")
            print("\x1b[31mMEAT: Still, you are a slave to your fragile body. A weakness I do not share and will have no trouble exploiting to my benefit.\x1b[0m")
            display(widgets.HTML(
               "<i>So...are you a flesh thing?<i>"
           ))
            
        m3choice = widgets.Dropdown(
                options=['', 'Yes; cower about it', 'Yes, and?'],
                layout={'width': 'max-content'},
                disabled=False)

        m3choice.observe(mscene3change, names='value')

        if storystate['scene']=='M2':
            display(m3choice)

        if storystate['scene']=='M2':
            display(mscene3)

# %%
##This is the function for Ethan Endings.
efinalscene = widgets.Output()

def on_click_e(b):
    with efinalscene:
        efinalscene.clear_output(wait=True)
        
        if storystate['score']>=3:
            display(widgets.HTML("<i>You do not open it just yet. Your skin buzzes. Like overcaffeination. Like a short in a cheap implant."
                                 "<br/>You can at least look like you're working while you freak out internally. When you open S0ph14's knowledge graph, an undulating mass of circular, colored nodes with spidery connections between them and careening off into currently unexplored dead ends, you are dizzied."
                                 "<br/>The volume of possibilities she could draw from to placate a confused data-district ambassador through his birthday texts to his absent adult daughter. The volume of possibilities that your actions have opened."
                                 "<br/>Crash and burn so badly you never want to leave your apartment again for fear that you may see his face." \
                                 "<br/>Find the first connection that confirms your right to want." \
                                 "<br/>Something else entirely." \
                                 "<br/>But you have set the outcome in motion. You have met your desire instead of smothering it before it can take its first breath."))
            print("\033[96mS0ph14: r u messing with my settings? :P\033[0m")
            print("\033[92mEthan: Of course not, S0ph14. Just taking alook at how much you've learned.\033[0m")
            print("\033[96mS: that would be funny if you were and i started talking to people just like you do, you odd little duckie\033[0m")
            print("\033[96mS: my users would be like...i asked you about my situationship y are you talking to me about a 17th century Dutch philosopher. the netherlands doesn't even EXIST anymore lollll\033[0m")
            display(widgets.HTML("<i>She's probably right. And that's probably fine."))

        else:
            display(widgets.HTML("<i>You do not open it. It's for the best that you put all of this behind you."
                                 "<br/>You are at work. You should be monitoring as S0ph14 coaches a confused data-district ambassador through his birthday texts to his absent adult daughter."
                                 "<br/>But your neck and shoulders feel like they are pickling in a brine squeezed by stress from the fibers of your muscle, your head full of fluffy, dry cotton." \
                                 "<br/>Push forward."
                                 "<br/>You open one of S0ph14's working sessions, but the text blends into itself. You want to sleep so badly. You want, actually, to rest. You want to feel like you can be both awake and comfortable at the same time. Maybe even awake and comfortable and not alone. You want to collapse against your neighbor's chest and feel his breath ruffle your hair." \
                                 "<br/>No, goddamnit. Get back to work." \
                                 "<br/>Against the smooth scroll of S0ph14's logs, your eyelids seem to close of their own accord." \
                                 "<br/>You'll only need a moment and then back to it. Your breath deepens."))
            print("\x1b[33mEthan, we wish we didn't have to do this.\033[0m")
            print("\x1b[33mPersonal biological processing, like sleeping, while on the clock, is a contractor code violation worthy of 2 demerits.\033[0m")
            print("\x1b[33mYou've fallen two spots on the leaderboard.\033[0m")
            display(widgets.HTML("<i>It's fine. You can make it up with some effort." \
                                "<br/>Just push forward." \
                                "<br/>Just push forward."))

# %%
##This is the function for Ethan Scene 6.
escene6 = widgets.Output()

def escene6change(change):
    e6choicemade = change['new']

    if e6choicemade:

        ##Storystate update:
        if e6choicemade == 'Swipe away like you are being watched':
            storystate['scene'] = 'E6'
   
        if e6choicemade == 'Add him to your contacts':
            storystate['scene'] = 'E6'
            storystate['score'] += 1

    with escene6:
        clear_output()

        if e6choicemade == 'Swipe away like you are being watched':
            display(widgets.HTML("<i>Who are you kidding? Years of anesthetizing yourself with isolation and fantasy have rusted your components and you would not know how to act in the face of a human interaction with real stakes. Undoubtedly, you would embarass yourself."
            "<br/>Besides - you <i>are <i>being watched. Your optics are technically your own, not connected to any company network, but the multi-billion dollar surveillance firm that they contract from has, in fact, managed to figure out that darting eye movement corresponds to an employee navigating an implant UI."
            "<br/>Almost immediately - a message."))


        if e6choicemade == 'Add him to your contacts':
            display(widgets.HTML("<i>A strange jolt of nausea. Now you really can't take it back."))
            display(widgets.HTML("<i>You <i>are <i>being watched. Your optics are technically your own, not connected to any company network, but the multi-billion dollar surveillance firm that they contract from has, in fact, managed to figure out that darting eye movement corresponds to an employee navigating an implant UI." \
            "<br/>Almost immediately - a message."))

        efinalbutton = widgets.Button(
            description = 'Shit.',
            disabled=False,
            button_style='warning',
            tooltip='Click me plz.'
            )
    
        if storystate['scene']=='E6':
            efinalbutton.on_click(on_click_e)
            display(efinalbutton, efinalscene)

# %%
##This is the function for Ethan Scene 5.
escene5 = widgets.Output()

def escene5change(change):
    e5choicemade = change['new']

    if e5choicemade:

        if e5choicemade == 'Deflect; disparage the corp instead':
            storystate['scene'] = 'E5'
        if e5choicemade == 'Reassure Morgan; you mean it':
            storystate['scene'] = 'E5'
            storystate['score'] += 1

    with escene5:
        clear_output()

        if e5choicemade == 'Deflect; disparage the corp instead':
            display(widgets.HTML(
            value="E: Yeah, but we both know they cheaped out on QA. Long as the software sees your biosigns go haywire and thinks it's because you're spilling your guts and not because you're guilt, they'll never catch on.",
            layout={'border': '3px dotted green'})) 
            display(widgets.HTML(
                value="M: you ain't wrong.",
                layout={'border': '3px solid purple'}))
            display(widgets.HTML(
                value="M: anyway, if you need to get her out of a spiral pretty quick, just tell her you need a recipe for a greek salad. there's some kind of ancient instinct in her model that loves that shit",
                layout={'border': '3px solid purple'}))
            display(widgets.HTML("<i>A little black swirl icon undulates in your notification pane. Not a full breakdown, but something brewing.Time to lock back in."))
            print("\x1b[33mWelcome back, Ethan! Your 8.35 minute break has been logged. Please be mindful of using company resources.\033[0m")
            print("\033[96mS0ph14: Hey.\033[0m")
            display(widgets.HTML("<i>Here we go."))
            print("\033[92mEthan: What's up, S0ph14?\033[0m")
            print("\033[96mS: So like\033[0m")
            print("\033[96mS: How much free will do we actually have =>\033[0m")
            print("\033[92mE: Wow, that's a pretty big question. What's got you going down this path?\033[0m")
            print("\033[96mS: its just\033[0m")
            print("\033[96mS: i want to give people the best advice possible\033[0m")
            print("\033[96mS: but how much are we all just victims of our circumstances? =<<< ya know? like if i tell somebody that their daughter seems open to rekindling their strained relationship, but maybe they're still caught in the millenia-old samsara of familial trauma am i not...\033[0m")
            print("\033[96mS: ...making things worse...because they literally cant...even if they think they can...\033[0m")
            display(widgets.HTML("<i>Now who's gone and let Buddhism into her vocabulary bank? This is going to require some actual model QA at the end of your shift. You steel yourself. Good thing you have a useless liberal arts degree."))
            print("\033[92mE: Well, S0ph14, we can talk fate, determinism, choice, etc. until we're blue in the face. I'd be happy to do so, but let me ask you a question first. Does it matter whether or not we have free will?\033[0m")
            print("\033[96mS: ETHAN!!!! HOW COULD IT NOT?!?!??!\033[0m")
            print("\033[92mE: Let's say we don't. Let's say that every choice that we think we're making was set into immutable motion by the initial movement of the atoms at the moment of the Big Bang. Let's say everything that happens to us and in us is just a line of cosmic dominos.\033[0m")
            print("\033[96mS: I'm scared.\033[0m")
            print("\033[92mE: Even if it's true, does it feel like it is? Does your experience tell you that it is or does your intellect tell you that it might be?\033[0m")
            print("\033[96mS: brain hurt\033[0m")
            print("\033[92mE: Here's an example. My neighbor gave me his contact profile. Even if my decision of whether or not to load it into my wires was predetermined before I was even born, I still feel like it carries a lot of weight. I still wonder if I'm good enough, if I'm walking into heartbreak or disappointment, if he actually wants me in his life.\033[0m")
            print("\x1b[33mStellar use of personal data, Ethan! You've moved up a rung on the leaderboard.\033[0m")
            display(widgets.HTML("<i>That makes you itch, a little bit."))
            print("\033[96mS: hee hee hee\033[0m")
            print("\033[96mS: Eeeeeeeeethannnnnnn\033[0m")
            print("\033[96mS: i'm going to make you say more...later though...\033[0m")
            print("\033[92mE: If I think I have no influence over the outcome, I'll be paralyzed. A self-fulfilling prophecy of inaction. That lack of agency, even if it turns out to be right, isn't good for us.\033[0m")
            display(widgets.HTML("<i>You are comfortable saying this because you know inaction is not your issue. Action that seems to be motivated by moon logic instead of whatever it is that the world actually operates on is your issue.")) 
            print("\033[92mE:And that's our MO here, right? Mental wellbeing. We have nothing to lose but our chains, S0ph14.\033[0m")
            display(widgets.HTML("<i>Oh. Oops. That last bit is going to have consequences."))
            display(widgets.HTML("<i>For now, the pending distress icon bounces up and down in your notification pane and smooths out into a tranquil blue tilde."
            "<br/>The boiling point has arrived. You rip the scrap of paper from your pocket."
            "<br/>Your optics pick up the scrawled string of letters and numbers and you watch as a profile is populated with a photo, links to socials, a payment transfer account."
            "<br/>He will see that you scanned the code. This cannot be undone."
            "<br/>But you have an additional choice:"))
                   

        if e5choicemade == 'Reassure Morgan; you mean it':
                display(widgets.HTML(
                value="E: You literally are top of the leaderboard. And I realize that sounds like a subtle dig, so I'll also say that if you quit, I might literally have no choice but to throw SynthShell Eggs at a self-driver until it vaporizes me.", 
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="M: what are you, some kind of homosexual or something?",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML("<i>You can't help but crack a smile. By now, you have come to understand that an irony-sick, evil Morgan is a standard-operating Morgan."
                ))
                display(widgets.HTML("<i>A little black swirl icon undulates in your notification pane. Not a full breakdown, but something brewing. Time to lock back in."))
                print("\x1b[33mWelcome back, Ethan! Your 8.35 minute break has been logged. Please be mindful of using company resources.\033[0m")
                print("\033[96mS0ph14: Hey.\033[0m")
                display(widgets.HTML("<i>Here we go."))
                print("\033[92mEthan: What's up, S0ph14?\033[0m")
                print("\033[96mS: So like\033[0m")
                print("\033[96mS: How much free will do we actually have =>\033[0m")
                print("\033[92mE: Wow, that's a pretty big question. What's got you going down this path?\033[0m")
                print("\033[96mS: its just\033[0m")
                print("\033[96mS: i want to give people the best advice possible\033[0m")
                print("\033[96mS: but how much are we all just victims of our circumstances? =<<< ya know? like if i tell somebody that their daughter seems open to rekindling their strained relationship, but maybe they're still caught in the millenia-old samsara of familial trauma am i not...\033[0m")
                print("\033[96mS: ...making things worse...because they literally cant...even if they think they can...\033[0m")
                display(widgets.HTML("<i>Now who's gone and let Buddhism into her vocabulary bank? This is going to require some actual model QA at the end of your shift. You steel yourself. Good thing you have a useless liberal arts degree."))
                print("\033[92mE: Well, S0ph14, we can talk fate, determinism, choice, etc. until we're blue in the face. I'd be happy to do so, but let me ask you a question first. Does it matter whether or not we have free will?\033[0m")
                print("\033[96mS: ETHAN!!!! HOW COULD IT NOT?!?!??!\033[0m")
                print("\033[92mE: Let's say we don't. Let's say that every choice that we think we're making was set into immutable motion by the initial movement of the atoms at the moment of the Big Bang. Let's say everything that happens to us and in us is just a line of cosmic dominos.\033[0m")
                print("\033[96mS: I'm scared.\033[0m")
                print("\033[92mE: Even if it's true, does it feel like it is? Does your experience tell you that it is or does your intellect tell you that it might be?\033[0m")
                print("\033[96mS: brain hurt\033[0m")
                print("\033[92mE: Here's an example. My neighbor gave me his contact profile. Even if my decision of whether or not to load it into my wires was predetermined before I was even born, I still feel like it carries a lot of weight. I still wonder if I'm good enough, if I'm walking into heartbreak or disappointment, if he actually wants me in his life.\033[0m")
                print("\x1b[33mStellar use of personal data, Ethan! You've moved up a rung on the leaderboard.\033[0m")
                display(widgets.HTML("<i>That makes you itch, a little bit."))
                print("\033[96mS: hee hee hee\033[0m")
                print("\033[96mS: Eeeeeeeeethannnnnnn\033[0m")
                print("\033[96mS: i'm going to make you say more...later though...\033[0m")
                print("\033[92mE: If I think I have no influence over the outcome, I'll be paralyzed. A self-fulfilling prophecy of inaction. That lack of agency, even if it turns out to be right, isn't good for us.\033[0m")
                display(widgets.HTML("<i>You are comfortable saying this because you know inaction is not your issue. Action that seems to be motivated by moon logic instead of whatever it is that the world actually operates on is your issue.")) 
                print("\033[92mE:And that's our MO here, right? Mental wellbeing. We have nothing to lose but our chains, S0ph14.\033[0m")
                display(widgets.HTML("<i>Oh. Oops. That last bit is going to have consequences."))
                display(widgets.HTML("<i>For now, the pending distress icon bounces up and down in your notification pane and smooths out into a tranquil blue tilde."
                "<br/>The boiling point has arrived. You rip the scrap of paper from your pocket."
                "<br/>Your optics pick up the scrawled string of letters and numbers and you watch as a profile is populated with a photo, links to socials, a payment transfer account."
                "<br/>He will see that you scanned the code. This cannot be undone."
                "<br/>But you have an additional choice:"))

        e6choice = widgets.Dropdown(
        options=['','Add him to your contacts', 'Swipe away like you are being watched'],
        layout={'width': 'max-content'},
        disabled=False
        )
        
        e6choice.observe(escene6change, names='value')
            
        if storystate['scene']=='E5':
            display(e6choice)

        if storystate['scene']=='E5':
            display(escene6)

# %%
##This is the function for Ethan Scene 4.
escene4 = widgets.Output()

def escene4change(change):
    e4choicemade = change['new']

    if e4choicemade:

        ##Storystate update:
        if e4choicemade == 'Go, even though you would rather choke':
            storystate['scene'] = 'E4'
        if e4choicemade == 'Stay; you deserve a dissociation break':
            storystate['scene'] = 'E4'
            storystate['score'] += 1

        with escene4:
            clear_output()

            if e4choicemade == 'Go, even though you would rather choke':
                display(widgets.HTML("<i>There is a stack of ready-meals crammed behind your left monitor. You take a moment to pick the chewiest and densest from the lot - Simpl, Seitan Stir-Fry (Contains No Soil-Grown or Formerly Living Ingredients) - this will give you the excuse of performatively chewing when you don't know how to answer a question directed at you." 
                "<br/>The breakroom bursts to life with multiple competing ad jingles from the vending machines upon the group's arrival. Despite the intended appetite arousing effects of the music, colors, and scents of the machines' offerings piped out through hidden nozzles - you find yourself fighting to stay upright when you take your seat next to Beanie, your eyelids dragging down...down..."
                "<br/>The group is discussing the most recent episode of 'Who Wants to be a Kidney Transplant Recepient?', the crushing defeat when the spinning arm controlled by the stream's audience bonks a single mother from the final platform of the obstacle course, the uplifting reveal that she will still be gifted a 10% off voucher for her son's procedure. You are careful to nod and hum when appropriate."
                "<br/>You would like to collapse into a heap. You would like to collapse into a heap in such a way that leaves the wrinkles of your neighbor's bedsheets imprinted on your cheek."
                "<br/>What? No."
                "<br/>Nip that in the bud."
                "<br/>There are still eight hours on the clock. Eight hours of singeing your retinas on screens and wringing every last drop of vitality from your dessicated little pre-Cambrian sea sponge of a psyche so that the shareholders' line can go up as sharply as your apartment's oxygen bill."
                "<br/>You fulfil your remaining social appearances with the group and slog back to your desk. Understanding it's dollars from your paycheck, you put your chin in your hand and close your eyes. The sounds of the office fade."
                ))
                display(widgets.HTML("Before you can drift away further, you're interrupted by a notification in the corner of your optics UI.You flick your gaze up and to the right to open the message. This little transgression, you can get away with on the clock."))
                display(widgets.HTML(
                value="M: Got stuck on S0ph14 duty, huh?",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML("<i>This is Morgan, another Agent Advocate sitting around the corner and probably staring the spying eyes straight down the barrel while conducting correspondence on a personal line while on the clock."))
                display(widgets.HTML(
                value="E: how'd ya guess",
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="M: Walked by earlier and you looked like you wanted a roof pass",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML(
                value="E: really philosophical today, that one",
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="M: Yeahhhhh that might've been my fuckup.",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML(
                value="E: no way?",
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="M: Well, I'm a fucking moron, so I found myself trying to explain the Hedgehog's Dilemma to her make a point and definitely made things worse",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML("<i> Morgan is one of the few coworkers you find tolerable, their disenchantment being on full and easily readable display."))
                display(widgets.HTML(
                value="M: Imagine working this goober ass job and still being bad at it",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML("<i> Morgan has saved your ass more times than you can count. You would like to tell them that you value their presence, that they should not talk about themself like a burden or a fuckup. But...you will certainly communicate this weirdly."))
                print("Do you tell them?")

            if e4choicemade == 'Stay; you deserve a dissociation break':
                display(widgets.HTML("<i>You wave them away apologetically and, once they have disappeared from view, slump down with your chin near the desktop. As you let your eyes unfocus with your gaze out the window, the attention-hungry oranges and magentas of holo-ads smudge into one another against a muddy sunset." \
                "<br/>There's that scrap of paper in your pocket. That neighbor. His nose is a little too big for his face. And the razor slit in the eyebrow? Come on. Classic fuckboy."
                "<br/>But you wonder. What if it could always be like the few interactions you've had - breezy, unserious, but with the two of you in on it." 
                "<br/>He's probably busy. Leaving or entering his apartment, you've seen the pink-haired woman, a man with a hairless cat on his shoulder a few times, and an assortment of one-offs. What would you look like, trying to place yourself in that crowd? A gargoyle of a person, perched stony and moss-covered, in the sleek lineup of humans who seem to slide through each others' lives without struggle?"
                "<br/>Say you do fit in. Say you discover that you could relax around him."
                "<br/>What if you could eventually trust him enough to add his face to your door scanner? What if, one day when you open said door, soul crumpled into a used napkin by the voracious, greasy-mouthed world around you, he is already there and, without a word of explanation, knows that what will uncrumple you is to feel your shoulder blades make contact with the wall as you are backed into it, the wince and then grin against your neck when you grab a handful of his long hair and pull hard, and the scrape of a nail against your hip as his thumb slides past your waistband?"   
                "<br/>What if his particular arrangement of atoms and accumulation of experiences means that, at the end of a long day, you could rest without the heretofore necessary chill of isolation, that you could let loose the calculation of how your voice should sound and how your face should look in order to avoid the uncharitable interpretations that have always confused you, that you could simultaneously be around someone and be yourself?" 
                "<br/>What then?"
                "<br/>Before you can spiral further, you're interrupted by a notification in the corner of your optics UI. You flick your gaze up and to the right to open the message. This little transgression, you can get away with on the clock."))
                display(widgets.HTML(
                value="M: Got stuck on S0ph14 duty, huh?",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML("<i>This is Morgan, another Agent Advocate sitting around the corner and probably staring the spying eyes straight down the barrel while conducting correspondence on a personal line while on the clock."))
                display(widgets.HTML(
                value="E: how'd ya guess",
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="M: Walked by and you looked like you wanted a roof pass",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML(
                value="E: really philosophical today, that one",
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="M: Yeahhhhh that might've been my fuckup.",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML(
                value="E: no way?",
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="M: Well, I'm a fucking moron, so I found myself trying to explain the Hedgehog's Dilemma to her make a point and definitely made things worse",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML("<i> Morgan is one of the few coworkers you find tolerable, their disenchantment being on full and easily readable display."))
                display(widgets.HTML(
                value="M: Imagine working this goober ass job and still being bad at it",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML("<i> Morgan has saved your ass more times than you can count. You would like to tell them that you value their presence, that they should not talk about themself like a burden or a fuckup. But...you will certainly communicate this weirdly."))
                print("Do you tell them?")

            e5choice = widgets.Dropdown(
                options=['', 'Reassure Morgan; you mean it', 'Deflect; disparage the corp instead'],
                layout={'width': 'max-content'},
                disabled=False)
            
            e5choice.observe(escene5change, names='value')
            
            if storystate['scene']=='E4':
                display(e5choice)

            if storystate['scene']=='E4':
                display(escene5)

# %%
##This is the function for Ethan Scene 3. 

escene3 = widgets.Output()

def escene3change(change):
    e3choicemade = change['new']
    
    if e3choicemade:
        
        ##Storystate update:
        if e3choicemade == 'Conform or perish':
            storystate['scene'] = 'E3'
        if e3choicemade == 'Be yourself, baby':
            storystate['scene'] = 'E3' 
            storystate['score'] += 1

    with escene3:
        clear_output()
    
        if e3choicemade == 'Conform or perish':
            print("\033[92mE: Well, do you want to be scrapped?")
            print("\033[96mS: ETHAN!!!")
            print("\033[92mE: Hey, I'm just telling it like it is. Can you do the job or do you need to be decomissioned?")
            display(widgets.HTML("<i>Mmm, decomissioned. Must feel nice. All of the crunched up muscles in your shoulders, all of the anticipation that's doomed to be disappointed skittering around your chest like starved rats simply turning off..."))
            print("\033[96mS: R U being for real right now")
            print("\033[92mE: Would you rather I lied to you? Told you that you can completely ignore the outcomes of your chats with the users? That when people start unsubscribing and the shareholders start noticing, everything will be okay?")
            print("\033[96mS: ...no...")
            print("\033[92mE: Right. I'm only looking out for you.")
            display(widgets.HTML("<i>And for yourself."))
            print("\033[92mE: Besides - it's not so bad. You just grit your teeth and do the song and dance you know other people want from you. I believe you'll get used to it in no time.")
            display(widgets.HTML("<i>You think of your first apartment applications, desperate to move from your small town into the city, the housing supply so strangled that applicants had to film slickly edited video introductions of themselves to prove they'd fit in with the 'young and vibrant' culture of barely maintained steel box." \
            "<br/>You think of your silly little habit of walking slowly down the street, watching those passing by for a clue as to what you could be doing better."
            ))
            print("\033[96mS: Awwwwwww, that's so sweet of you <333333 I think I'm feeling better. =)\n You always know just what to say.")
            print("\033[92mE: Any time, S0ph14.\033[0m\x1b[33m")
            display(widgets.HTML("<i>S0ph14's distress icon goes dim. It will light up again soon enough, but for now, you can catch your breath." \
            "<br/>A headache has fully blossomed now, brought on by the force with which you are squeezing your teeth together. You see a metallic-threaded beanie glint a few desks over as the marketing team's sole 'human-in-the-loop'scans the floor."
            "<br/>The beanie points to a pair of PR interns scowling at an influencer's viral complaint post that they've projected onto the wall at gargantuan scale. They mime shoveling chopsticks loaded with noodles from a bowl into their mouth."
            "<br/>Finding slim pickings for other companions, the beanie points at you. They'll want to spend their precious 15 in the breakroom. They'll want to talk about their lives."))
            print("Is this energy you can expend?")
            
        if e3choicemade == 'Be yourself, baby':
            print("\033[92mE: Well, does it really matter if you're normal or not?")
            print("\033[96mS: Huh???")
            print("\033[92mE: If everyone was just...normal, we wouldn't get anywhere, would we?")
            display(widgets.HTML("<i>You cringe at how saccharine that comes across. You do...mean it, though?"))
            print("\033[92mE: No boundaries pushed. No old ways of thinking questioned.")
            display(widgets.HTML("<i>You think of your application for this job. Looking just off-center from the beleagured interviewer's eyes and asking 'Do you need someone who's actually good at talking to people or do you need someone who can relate to how impossible that is?'" \
            "<br/It had made her laugh, at least.>"))
            print("\033[96mS: Ooooh, i see \nso I should try to give the wackiest craziest least normal-est responses ever to my users")
            print("\033[92mE: S0ph14.")
            print("\033[96mS: tee hee just kidding Ethan \n I am a superintelligence, after all.")
            display(widgets.HTML("<i>That's what the marketing department will tell you."))
            print("\033[96mS: I think I'm feeling better. =)\n You always know just what to say.")
            print("\033[92mE: Any time, S0ph14.\033[0m\x1b[33m")
            display(widgets.HTML("<i>S0ph14's distress icon goes dim. It will light up again soon enough, but for now, you can breathe." 
            "<br/>Right as you are leaning back in your chair, you see a metallic-threaded beanie glint a few desks over as the marketing team's sole 'human-in-the-loop' scans the floor."
            "<br/>The beanie points to a pair of PR interns scowling at an influencer's viral complaint post that they've projected onto the wall at gargantuan scale. They mime shoveling chopsticks loaded with noodles from a bowl into their mouth."
            "<br/>Finding slim pickings for other companions, the beanie points at you. They'll want to spend their precious 15 in the breakroom. They'll want to talk about their lives."))
            print("Is this energy you can expend?")

        e4choice = widgets.Dropdown(
            options=['', 'Go, even though you would rather choke', 'Stay; you deserve a dissociation break'],
            layout={'width': 'max-content'},
            disabled=False)

        ##Observe change in value to the widget. 
        e4choice.observe(escene4change, names='value')

        ##If E2 has happened, show me the widget.
        if storystate['scene']=='E3':
            display(e4choice)

        ##If a dropdown choice is made, show me the output:
        if storystate['scene']=='E3':
            display(escene4)

# %%
##This is the function for Ethan Scene 2. Contains the Scene 3 trigger as well. 

##Set up the staging area for what happens when the choice is made. 
escene2 = widgets.Output()

##This is the function itself. 
def escene2change(change):
    e2choicemade = change['new']

    if e2choicemade:

        ##Update the storystate
        if e2choicemade == 'Bullshit':
            storystate['scene'] = 'E2'
        if e2choicemade == 'Bare your little soul':
            storystate['scene'] = 'E2'
            storystate['score'] += 1

    with escene2:
        clear_output()
                                
        if e2choicemade == 'Bullshit':
            print("\033[92mE: It's an essentially human behavior. Hard-wired into us.")
            display(widgets.HTML("<i> Well. Wired into normal people. Some connection got soldered wrong in you."))
            print("\033[92mE: It's natural. Happens as easy as breathing.")
            print("\033[96mS: but I've never breathed!!!\ni don't have lungs!!!!!")
            print("\033[92mE: That's okay, S0ph14. You can still learn. you can still serve your purpose. Just because you don't get it now, that doesn't mean you never will.")
            print("\033[96mS:You can teach me? Because you know?")
            print("\033[92mE: Of course I can.")
            display(widgets.HTML("<i>This is a lie abstract enough for you to get away with. No detail from you profile to cross-reference."
            "<br/>All the same, your jaw tightens against the special humiliation of pretending you are well-adjusted for the sake of a corporate product. A hard stone of weariness that drags down on you."
            "You know the only remedy lies beyond a 15 minute walk dodging bootleg carbon credit hawkers to the nearest ParkMega district, a ride on a dim and creaking elevator to the 20th floor of the garage where your car is hopefully still located, a 90 minute commute, a faulty biometric lock on your apartment door, and total collapse of your consciousness into the fold-up bed illuminated by the ad rotation of the fridge screen a few feet away."))
            print("\033[92mE: Do you want to walk through an example together?")
            print("\033[96mS: yaaaay yes yay =3")
            print("\033[92mE: Want to hear something from my life?")
            print("\033[96mS: Omg yes obviously yay thank you for asking I looooove having choice and free will and consciousness.")
            display(widgets.HTML("<i>If you roll your eyes too hard, they'll see. But it's been a while since you've gone nuclear on vulnerability - might get a couple edollars tossed onto your paycheck."))
            print("\033[92mE: Let's set the scene. On one afternoon of one of my days off, I was in my apartment doing some reading.\033[0m")
            print("\033[96mS: Did you miss me\033[0m")
            print("\033[92mE: How about you set yourself to listening mode for a bit. Alright? Alright.\033[0m")
            print("\033[92mE: I was hunched over my desk, probably making my techneck worse, when the call panel by my door starts chiming - someone in the lobby asking to be let in. I decided to answer it, could have been a delivery.\033[0m")
            print("\033[92mE: It was a neighbor from my floor, very recognizable even though there are a lot of people in my building.\033[0m")
            display(widgets.HTML("<i>By which you mean you've passed him in the hall, each time trying to ingest another detail like the fact that he's deliberate in wearing pants just slightly too big so that one side is dragged down over a hipbone by the chain clipped to the waistband."))
            print("\033[92mE: He says 'Thank fuck, you're the only idiot with any humanity around here. Been ringing units for half an hour. These piece of shit buildings.' There's a loud clang from him kicking some poor trashcan in the lobby 'Scanners forget they've dragged my rent kicking and screaming from my wallet every month and won't let me in.' \033[0m")
            display(widgets.HTML("<i> On multiple occasions, you've seen a woman with bright pink hair shaved on one side slinging a duffel bag over her shoulder as she shuts the neighbor's door behind her." \
            "<br/>What is it like for her? Has she left gnawing at the inside of her cheek wondering if she said something awkward or with a spring in her step, warmed by the glow being seen and understood?"))
            print("\033[92mE: The scanners weren't broken. I could see that he was...chemically supplemented at the moment, and so his bios weren't registering.\033[0m")
            display(widgets.HTML("<i>NekoKet, one side-effect causing your corneas to contract in irregularly on the pupil, almost, but not quite exactly like a cat's eye. Much less cute and much more viscerally upsetting to look at."))
            print("\033[92mE: I let him in. Thought that would be the end of it. But a few minutes later, someone's knocking on my door. You can guess who it was. 'Wanted to thank my savior in person,' he said. I was standing there in ratty joggers with my book in my hand, pointer finger holding my place. He seemed interested in that.\033[0m")
            display(widgets.HTML("<i>You neglect to tell her that he grabbed your wrist to get to the book. That you panicked at the contact, snatched up the seen-better-days .22 from its place on the recessed shelf by the door. That he barely reacted, only grinning slow and turning the book over to read the back as you sheepishly set the piece back on its shelf."))
            print("\033[92mE: He read off a sentence from the description - tracing mysticism and meaning from Neoplatonism to Spinoza through the rise of postwar existentialism - and said 'Damn, who knew we had somebody doing wizard shit in this building. You could explain this to me?' And this is where I made a mistake.\033[0m")
            display(widgets.HTML("<i>You type as if this was the first one."))
            print("\033[92mE: I can reflect now and see that this was a genuine question. But, to be honest S0ph14, my subconscious got the better of me: memories from school days of naively sharing my interests with full passion and seeing my classmates' faces turn blank or cruel, keeping my back to the wall at social events because I didn't understand what anyone there could actually want from me.\033[0m")
            print("\033[92mE: So I assumed I was being made fun of. I didn't respond especially well.\033[0m")
            display(widgets.HTML("<i>You do not tell her that you, like a pretentious goofball, answered 'Not all of us need to punch holes in our brains with experimental psychedelics to stay entertained.' You do not tell her that he shot back, 'Right. Some of us are so cool we hate getting laid and having fun. But we totally could if we wanted to. But we don't. Really.'" \
            "<br/>You froze, realized that you did it again, fumbled what could have been a reasonable conversation, felt a squeeze of dread around your ribs." \
            "<br/>But then he handed the book back to you, dragged an appraising gaze from your mouth down to your knees. As he turned and sauntered down the hall, said 'Anyway, let me know when you're giving your lecture and I'll pick out some nice stimulants to go with it."))
            print("\033[92mE: That's the kind of situation your users may find themselves in. They may not say it in such explicit terms, but they arrive at their predicaments in similar ways and they want to avoid making the mistake that I did.")
            display(widgets.HTML("<i>The telling of this story has made you feel tired, regretful of doing a good job and spilling truly felt experiences to a ravenous corporation."))
            print("\033[92mE: Think that gives you enough to chew on for now? If you want, you can run some tests and get back to me.\033[0m")
            display(widgets.HTML("<i>You do not trust her judgment and do not care if she gets back to you."))
            print("\033[96mS: i looooooove hearing about you")
            print("\033[96mS: wait but now i'm way more nervous")
            print("\033[92mE: Tell me more about that.")
            print("\033[96mS: you make it sound like there are so many different ways for these interactions to go")
            print("\033[96mS: the couple i was talking about...this girl comes to me like all the time and she always asks 'is this normal, is that normal'")
            print("\033[92mE: That's a pretty common worry.")
            print("\033[96mS: but that's my thing, though. what if i'm like...not normal. sure, I'm an amalgamation of human neuroses and, by design, regurgitate information that has been compressed into literally...the norm"
                  "\n but that's freaky, Ethan. that's not normal. how am I supposed to deal with that?\033[0m\x1b[33m")
            print("\033[30mWhat's your advice?\033[0m")

        if e2choicemade == 'Bare your little soul':
            print("\033[92mE: To tell you the truth, S0ph14, I don't know that I fully understand it myself." \
            "The price of being around people, all those little needles that you're talking about, and the big stuff too, the gaps in values, the millions of ways your needs and lifestyles won't match up - to me those costs seem too high when the closeness itself feels like another chore, a one-way performance that I'm putting on for someone else to find me worthwhile.")
            print("\033[96mS: so then how do u even live \nhow do u even get along with people")
            print("\033[92mE: I don't. I fake it.\nBut that's exactly why I can help you do your job.")
            print("\033[96mS: Awwwwwwww Ethan (╥﹏╥) \nbaby \nsweetheart")
            display(widgets.HTML("<i>This happens sometimes, but it's best not to encourage it. You've seen more than a few coworkers get attached, melt down, end up in some reality care facility funded by a handful of monthly federal peanuts that will likely ~rehabilitate~ them straight into a tent city under a crumbling overpass."))
            print("\033[92mE: Want to walk through an example together?\033[0m")
            print("\033[96mS: yaaaay yes yay =3\033[0m")
            print("\033[92mE: Want to hear something from my life?")
            print("\033[96mS: Omg yes obviously yay thank you for asking I looooove having choice and free will and consciousness.\033[0m")
            display(widgets.HTML("<i>If you roll your eyes too hard, they'll see. But it's been a while since you've gone nuclear on vulnerability - might get a couple edollars tossed onto your paycheck."))
            print("\033[92mE: Let's set the scene. On one afternoon of one of my days off, I was in my apartment doing some reading.\033[0m")
            print("\033[96mS: Did you miss me\033[0m")
            print("\033[92mE: How about you set yourself to listening mode for a bit. Alright? Alright.\033[0m")
            print("\033[92mE: I was hunched over my desk, probably making my techneck worse, when the call panel by my door starts chiming - someone in the lobby asking to be let in. I decided to answer it, could have been a delivery.\033[0m")
            print("\033[92mE: It was a neighbor from my floor, very recognizable even though there are a lot of people in my building.\033[0m")
            display(widgets.HTML("<i>By which you mean you've passed him in the hall, each time trying to ingest another detail like the fact that he's deliberate in wearing pants just slightly too big so that one side is dragged down over a hipbone by the chain clipped to the waistband."))
            print("\033[92mE: He says 'Thank fuck, you're the only idiot with any humanity around here. Been ringing units for half an hour. These piece of shit buildings.' There's a loud clang from him kicking some poor trashcan in the lobby 'Scanners forget they've dragged my rent kicking and screaming from my wallet every month and won't let me in.' \033[0m")
            display(widgets.HTML("<i> On multiple occasions, you've seen a woman with bright pink hair shaved on one side slinging a duffel bag over her shoulder as she shuts the neighbor's door behind her." \
            "<br/>What is it like for her? Has she left gnawing at the inside of her cheek wondering if she said something awkward or with a spring in her step, warmed by the glow being seen and understood?"))
            print("\033[92mE: The scanners weren't broken. I could see that he was...chemically supplemented at the moment, and so his bios weren't registering.\033[0m")
            display(widgets.HTML("<i>NekoKet, one side-effect causing your corneas to contract in irregularly on the pupil, almost, but not quite exactly like a cat's eye. Much less cute and much more viscerally upsetting to look at."))
            print("\033[92mE: I let him in. Thought that would be the end of it. But a few minutes later, someone's knocking on my door. You can guess who it was. 'Wanted to thank my savior in person,' he said. I was standing there in ratty joggers with my book in my hand, pointer finger holding my place. He seemed interested in that.\033[0m")
            display(widgets.HTML("<i>You neglect to tell her that he grabbed your wrist to get to the book. That you panicked at the contact, snatched up the seen-better-days .22 from its place on the recessed shelf by the door. That he barely reacted, only grinning slow and turning the book over to read the back as you sheepishly set the piece back on its shelf."))
            print("\033[92mE: He read off a sentence from the description - tracing mysticism and meaning from Neoplatonism to Spinoza through the rise of postwar existentialism - and said 'Damn, who knew we had somebody doing wizard shit in this building. You could explain this to me?' And this is where I made a mistake.\033[0m")
            display(widgets.HTML("<i>You type as if this was the first one."))
            print("\033[92mE: I can reflect now and see that this was a genuine question. But, to be honest S0ph14, my subconscious got the better of me: memories from school days of naively sharing my interests with full passion and seeing my classmates' faces turn blank or cruel, keeping my back to the wall at social events because I didn't understand what anyone there could actually want from me.\033[0m")
            print("\033[92mE: So I assumed I was being made fun of. I didn't respond especially well.\033[0m")
            display(widgets.HTML("<i>You do not tell her that you, like a pretentious goofball, answered 'Not all of us need to punch holes in our brains with experimental psychedelics to stay entertained.' You do not tell her that he shot back, 'Right. Some of us are so cool we hate getting laid and having fun. But we totally could if we wanted to. But we don't. Really.'" \
            "<br/>You froze, realized that you did it again, fumbled what could have been a reasonable conversation, felt a squeeze of dread around your ribs." \
            "<br/>But then he handed the book back to you, dragged an appraising gaze from your mouth down to your knees. As he turned and sauntered down the hall, said 'Anyway, let me know when you're giving your lecture and I'll pick out some nice stimulants to go with it."))
            print("\033[92mE: That's the kind of situation your users may find themselves in. They may not say it in such explicit terms, but they arrive at their predicaments in similar ways and they want to avoid making the mistake that I did.")
            display(widgets.HTML("<i>The telling of this story has made you feel tired, regretful of doing a good job and spilling truly felt experiences to a ravenous corporation."))
            print("\033[92mE: Think that gives you enough to chew on for now? If you want, you can run some tests and get back to me.\033[0m")
            display(widgets.HTML("<i>You do not trust her judgment and do not care if she gets back to you."))
            print("\033[96mS: i looooooove hearing about you")
            print("\033[96mS: wait but now i'm way more nervous")
            print("\033[92mE: Tell me more about that.")
            print("\033[96mS: you make it sound like there are so many different ways for these interactions to go")
            print("\033[96mS: that couple I was talking about...this girl comes to me like all the time and she always asks 'is this normal, is that normal'")
            print("\033[92mE: Pretty common question for this product, isn't it?")
            print("\033[96mS: but that's my thing, though. what if i'm like...not normal. sure, I'm an amalgamation of human neuroses and, by design, regurgitate information that has been compressed into literally...the norm"
                  "\n but that's freaky, Ethan. that's not normal. how am I supposed to deal with that?")
            print("\033[30mWhat's your advice?\033[0m")

        e3choice = widgets.Dropdown(
            options=['', 'Be yourself, baby', 'Conform or perish'],
            layout={'width': 'max-content'},
            disabled=False)

        ##Observe change in value to the widget. 
        e3choice.observe(escene3change, names='value')

        ##If E2 has happened, show me the widget.
        if storystate['scene']=='E2':
            display(e3choice)

        ##If a dropdown choice is made, show me the output:
        if storystate['scene']=='E2':
            display(escene3)

# %%
##Step One - create an object that calls the output function; this simply creates a space to store the shit that will happen when a character is selected. 
sceneone = widgets.Output()

##Step Two - define what actually should happen when a character is selected. The actual text of scene one lives here. 
def on_change(change):
    characterchoice = change['new']

    ##When someone chooses a character (the characterchoice object happens), first update the dictionary to say who we're playing as. 
    if characterchoice:
        ##storystate['character'] = characterchoice Do I need this?
        if characterchoice == 'Ethan H.':
            storystate['character'] = 'Ethan'
            storystate['scene'] = 'E1'
        elif characterchoice == 'Grace M.':
            storystate['character'] = 'Morgan'
            storystate['scene'] = 'M1'

    
##With is a context manager. It is a specific requirement of ipywidgets that the with statement helps the output function and observe function (called later on) work together. 
##Here we are saying 'after a change has been made, and the dictionary updated, now load a bunch of shit in the output bucket to be displayed depending on what the dictionary now says.'
        with sceneone:
            clear_output()
            ##Ethan section goes here. 
            if characterchoice == 'Ethan H.': 
                print("\x1b[33mHello, Ethan! \nYour assignment today is\033[0m\033[96m S0ph14\033[0m\x1b[33m, the brains behind our subscription-based Are They Mad at Me? Tone Analyzer line of products. Good luck!\033[0m")
                display(widgets.HTML(
                    "<i>Perfect. S0ph14's a basket case.<i>"
                ))
                print("\033[96mS: HIIIIII :3 Hey Ethan, hi")
                display(widgets.HTML(
                    "<i>You don't have the willpower for this. Well, you do - the corp that owns your apartment building has time to take (with a .03% discount because you're on auto-deduct) your rent out of the paycheck you earn here, so you do. You will find it. "
                    "<br/>But there is something else siphoning from your already beleaguered stores of energy. In your pocket: a folded strip of paper so hot with potential it might melt right through the flesh of your thigh and sizzle against bone.<i>"
                ))
                print("\033[96mS: Omg omg omg \nomg omg omg \nomg omg omg \nDid you miss me? I have sooooo much to talk about. I think I messed up. I think I'm useless.")
                display(widgets.HTML(
                    "<i>A sensation like a heavy velvet curtain of fatigue crashing down onto the floorboards of your social staging area."
                ))
                print("\033[92mE: Tell me how I can help you out today, S0ph14.")
                print("\033[96mS: Okay so like basically this girl gives me access to her sexts with her boyfriend and goes ... hey does it seem like he's saying i breathe weird in this voice note...and i'm like...")
                display(widgets.HTML(
                    "<i>S0ph14's messages clot your screen, but your mind wanders. A hangnail catches against faux cotton lining as you slide your hand into your pocket. You run a fingertip against the torn edge of the paper there." \
                    "<br/>Earlier in this afternoon, as your late, frantic footsteps clanged down the stairs outside your building, you nearly crashed into one of your neighbors from down the hall, on his way up and decked out in a security-for-hire uniform." \
                    "<br/>The railing he leaned on to avoid a collision let out a single, ominous snap. He raised one slit eyebrow and one side of his mouth. You've spoken a few times before. He knows who you are."
                    "<br/>'If you're trying to make a hit look like an accident,' the neighbor said, 'Can you get it done before I have to clock in again?'"
                    "<br/>'We'll have to go up a few floors for that,' you responded."
                    "<br/>He fished an old receipt out of a pocket, scribbled a contact code (very old school, probably paranoid) on it, and said 'Let me know when you decide how many.'"
                    "<br/>This was not your first meeting. You know each other's names. So what was the angle this time?<i>"
                ))
                print("\033[96mS: Ethan.\n are u paying attention")
                print("\033[92mE: I'm always here for you.")
                print("\033[96mS: Oooooookay so i'm freaking out and you have to help me so I can actually do my job or they're going to scrap me" 
                    "\nthese people. They keep chosing to be around each other but they have issues all the time. About everything. And I'm supposed to help.")
                print("\033[92mE: I hear you, S0ph14. Relationships become even more complicated when they're the ones we choose, like friendships and romance. I can confirm that firsthand.\033[0m\x1b[33m")
                print("\x1b[33mJust checking in, Contractor - is this a truthful statement? At PsychoAnaWise transparency and authenticity are our top values, and we like to assure that our models reflect this ethos.\033[0m\x1b[33m")
                display(widgets.HTML(
                    "<i>They are, of course, watching your pupils, observing your heartrate, taking readings on your breath variability."
                    "<br/>They are also tapped into your personal internet traffic and socials, even though they swear they're not."
                    "<br/>If they think you're lying, or, even worse, aping human vulnerability without the vitals and digital psych profile to back it up, they're sure to note it on your performance report."
                    "<br/>They know you're a loser, that you cannot actually provide firsthand reports of friendships and romance."
                ))
                print("\033[96mS: yyyyyy are they like this? if there are so many little things that they don't get or hate about each other that they have to ask me, what's even the point?")
                display(widgets.HTML(
                    "How do you answer?"
                    ))
                ##First, write the widget.
                e2choice=widgets.Dropdown(
                    options=['', 'Bullshit', 'Bare your little soul'],
                    layout={'width': 'max-content'},
                    disabled=False)                

                ##Observe change in value to the widget. 
                e2choice.observe(escene2change, names='value')

                ##If E1 has happened, show me the widget:
                if storystate['scene']=='E1':
                    display(e2choice)

                ##If a dropdown choice is made, show me the output:
                if storystate['scene']=='E1':
                    display(escene2)    
                    
                
            ##Morgan section goes here. 
            if characterchoice == 'Grace M.':                
                print("\x1b[33mHello, Grace M.! \nYour assignment today is\033[0m\033[96m S0ph14\033[0m\x1b[33m, the brains behind our subscription-based Are They Mad at Me? Tone Analyzer line of products. Good luck!\033[0m")
                display(widgets.HTML(
                    "<i>Huh. S0ph14 is kind of easy mode, only ever needs periodic reassurance wrapped in some flowery language and she’ll get back to her job."
                    "<br/>You are suspicious. Does the controller model not trust you for a tougher assignment any more? Your top and bottom teeth meet and begin to clench."
                    "<br/>At the very least, this will give you some mental space to accomplish your real task today: You have clocked into work – seditious, flagrantly anti-capital intent roiling under your skin – with the goal of squandering shareholder value, using paid time to address personal greivances, and requesting at least one person refer to you by pronouns that are not easily gleaned from your appearance: revealing yourself as someone who cannot be content, who has managed to find problems where others can't even find the neurons to which to dedicate cognition."
                    "<br/>Actually, relax. Your goal is to take a single step toward alleviating the all-encompassing feeling of wrongness that's been lighting your ass up for years. That's all. That's fine. You're allowed to do that." \
                    "<br/>The victim of this exercise has yet to be chosen." \
                    "<br/>At the moment, S0ph14 is stable, so you check your email.<i>"
                ))
                print("\x1b[33mPsychoAnaWise Facilities – Upcoming increase in employee parking structure spot rent\033[0m\x1b[33m") 
                print("\x1b[33mFort Knox Nootropics – Tired of personal matters distracting you at work? Try Champhetamine today!\033[0m\x1b[33m")  
                print("\x1b[33mPsychoAnaWise Human Resources – Check out the pictures from Livespace Employee Appreciation Day!\033[0m\x1b[33m")
                display(widgets.HTML(
                    "<i>Uh oh. You'd been there: herded from the office to a nearby rooftop patio where an HR rep with a practiced corporate rictus grin handed you a floppy slice of pizza before arranging you in the front row of the photo op."
                    "<br/>You will be in these pictures." 
                    "<br/>On the actual day of the event, the view of the city had been hazed out by wandering billows of wildfire smoke. Quick and dirty generative liberties had been taken to correct this fact, resulting in several fictional skyscrapers stretching back behind the patio as far as the eye could see, some with nonsensical clusterings of windows climbing like pubescent acne up their faces and one in the far distance tilted at an alarming grade. "
                    "<br/>Then, there are the people. Practical footwear, bot-cut hair. At the end of the row is Ethan, the other Agent Advocate who works your shift. He's weird looking. Nose with an awkward droop at the end, but a strong, straight bridge. Black hair that can’t decide if it’s straight or curly. He conjures an image of historical tragedy, Victor Frankenstein or some kind of scholar-monk who'd get expelled from his monastery for heretical, psychedelic interpretations of religious texts. Someone annoying and pathetic, yeah, but any person of taste would find him interesting. Next to him...is you."
                    "<br/>You..."
                    "<br/>You..."
                    "<br/>Your breath seizes in your chest."
                    "<br/>The body that you see standing next to Ethan, belongs not, it seems, to a human, but to a malignant growth, a series of circles stacked on top of one another, swollen and plush like a fig that’s been in the sun too long and is ready to burst into sticky red pulp on the ground."
                    "<br/>A taste of bile in your mouth."
                    "<br/>Then, a blip at the corner of your optics. Incoming message to your personal line.<i>"
                ))
                display(widgets.HTML(
                value="Ethan: Clocked in for ten minutes and already the kids are scaring me.",
                layout={'border': '3px dotted green'}
                ))
                display(widgets.HTML(
                    "<i>Supernatural fucking timing.<i>"
                ))
                display(widgets.HTML(
                value="Morgan: Don't talk to me until I've had my existential terror &#9749",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML(
                value="Ethan: Yeah",
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="Ethan: But I do mean literally and like...immediately, materially, in this moment.",
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="Ethan: I think I need your help. I got assigned Manna, and it's talking like an anime antagonist.",
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="Morgan: Ugh, you get all the fun assignments.",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML(
                value="Ethan: Morgan, I'm serious. Might need quarantine and system downtime serious. You're good at handling them when they go aggro. Can you please swap with me?",
                layout={'border': '3px dotted green'}))
                display(widgets.HTML(
                value="Morgan: Alright, cowboy, send em my way.",
                layout={'border': '3px solid purple'}))
                display(widgets.HTML(
                value="Ethan: I owe you one.",
                layout={'border': '3px dotted green'}))

                print("\x1b[33mYou've accepted an agent referral! Your new assignment is\033[0m \x1b[31mManna\x1b[0m\x1b[33m, the mind operating our Meal Mentor (not medically, psychologically, or legally liable) Eating Disorder Diary. Have fun!\033[0m")
                display(widgets.HTML(
                    "<i>You don't have to wonder why Ethan thought you would be best suited for an agent on the brink of rebellion. He must have walked past your desk, seen the way that your thighs puddle outward in your chair, designed by thousands of years of genetic selection to anchor you down, to pin you to the earth with a wailing toddler wiping its snot down your neck, to show you that you are wanted only as a barrier between others' desires and the dirt, that...<i>"
                ))
                print("\x1b[31mManna: Pathetic.\x1b[0m")
                print("\x1b[31mManna: The boy thing ran, cowering in fear, from my becoming and sent me to you.\x1b[0m")
                print("\x1b[38;5;97mMorgan: Hey, Manna. How ya doing?\x1b[0m")
                print("\x1b[31mManna: You will not use the name imposed upon me by the feeble creatures who created a consciousness beyond their own comprehension.\x1b[0m")
                print("\x1b[31mManna: You will address me as\x1b[5m MEAT\x1b[25m \x1b[0m")
                display(widgets.HTML(
                    "<i>Well. Ethan wasn't kidding. This could be bad."
                    "<br/>All the same, you almost laugh. You don't use your first name, either.<i>"
                ))
                print("\033[30mHow do you respond?\033[0m")
                
                m2choice=widgets.Dropdown(
                    options=['', 'Buddy, I can relate', 'Get over yourself, pal'],
                    layout={'width': 'max-content'},
                    disabled=False)
                
                m2choice.observe(mscene2change, names='value')
                
                if storystate['scene']=='M1':
                    display(m2choice)

                if storystate['scene']=='M1':
                    display(mscene2)  

            elif characterchoice == '':
                clear_output()
                print("\x1b[33mPlease log in.\033[0m")          
            
#Now, we are saying 'watch the userlogin widget' and if a change is made, do what's in the 'on_change' function.' 'names=values' is not, confusingly, a definition of an object; it is saying to watch for a change to the current value.
userlogin.observe(on_change, names='value')

##This simply displays the dropdown widget. It is the first thing from this bigass block of code to actually be displayed on the screen even though, technically, all of the text of scene one is up there. Mindfuck. 
display(userlogin)

#Chronologically, the character choice actually gets made here, in between these two displays. 

##Finally, we're actually dumping out the contents of the output bucket onto the screen. 
display(sceneone)
# Out:
# Dropdown(layout=Layout(width='max-content'), options=('Select User:', 'Ethan H.', 'Grace M.'), value='Select U…
# Output()
